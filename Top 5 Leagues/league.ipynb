# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("top5_leagues_player.csv")

# %%
data
# Out:
#       Unnamed: 0                name                     full_name  age  \
# 0              0             Ederson                           NaN   29
# 1              1       Stefan Ortega          Stefan Ortega Moreno   30
# 2              2        Scott Carson             Scott Paul Carson   37
# 3              3          Rúben Dias  Rúben Santos Gato Alves Dias   26
# 4              4          Nathan Aké           Nathan Benjamin Aké   28
# ...          ...                 ...                           ...  ...
# 2607        2607       Moussa Djitté         Moussa Kalilou Djitté   23
# 2608        2608  Mounaïm El Idrissy                 منعم الإدريسي   24
# 2609        2609      Moussa Soumano                           NaN   17
# 2610        2610      Romain Hamouma                           NaN   36
# 2611        2611      Yoann Touzghar                           NaN   36
#
#       height                 nationality place_of_birth  price  max_price  \
# 0       1.88            Brazil  Portugal    Osasco (SP)  45.00      70.00
# 1       1.85              Germany  Spain     Hofgeismar   6.00       6.00
# 2       1.88                     England     Whitehaven   0.25       6.00
# 3       1.87                    Portugal        Amadora  75.00      75.00
# 4       1.80  Netherlands  Cote d'Ivoire       Den Haag  35.00      40.00
# ...      ...                         ...            ...    ...        ...
# 2607    1.80                     Senegal      Diattouma   2.00       2.00
# 2608    1.81             France  Morocco      Martigues   1.80       1.80
# 2609     NaN                France  Mali            NaN   0.90       0.90
# 2610    1.79             France  Algeria    Montbéliard   0.60       7.00
# 2611    1.80             Tunisia  France        Avignon   0.50       1.75
#
#                      position  shirt_nr   foot        club contract_expires  \
# 0                  Goalkeeper        31   left    Man City       2026-06-30
# 1                  Goalkeeper        18  right    Man City       2025-06-30
# 2                  Goalkeeper        33  right    Man City       2023-06-30
# 3      Defender - Centre-Back         3  right    Man City       2027-06-30
# 4      Defender - Centre-Back         6   left    Man City       2025-06-30
# ...                       ...       ...    ...         ...              ...
# 2607  Attack - Centre-Forward        28  right  AC Ajaccio       2023-06-30
# 2608  Attack - Centre-Forward         7  right  AC Ajaccio       2023-06-30
# 2609  Attack - Centre-Forward        34    NaN  AC Ajaccio       2026-06-30
# 2610  Attack - Centre-Forward        17  right  AC Ajaccio       2023-06-30
# 2611  Attack - Centre-Forward         9  right  AC Ajaccio       2024-06-30
#
#      joined_club        player_agent outfitter league
# 0     2017-07-01           Gestifute      Puma    EPL
# 1     2022-07-01         neblung ...       NaN    EPL
# 2     2021-07-20           Wasserman      Puma    EPL
# 3     2020-09-29           Gestifute      Nike    EPL
# 4     2020-08-05           Wasserman      Nike    EPL
# ...          ...                 ...       ...    ...
# 2607  2023-01-31       FS Management       NaN  Other
# 2608  2019-07-01            N.Agency       NaN  Other
# 2609  2023-01-01                 NaN       NaN  Other
# 2610  2022-07-01  Gallea Gestion S.A       NaN  Other
# 2611  2022-08-24         AGJ SP MGMT       NaN  Other
#
# [2612 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2612 entries, 0 to 2611
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2612 non-null   int64
#  1   name              2612 non-null   object
#  2   full_name         1480 non-null   object
#  3   age               2612 non-null   int64
#  4   height            2601 non-null   float64
#  5   nationality       2612 non-null   object
#  6   place_of_birth    2595 non-null   object
#  7   price             2602 non-null   float64
#  8   max_price         2606 non-null   float64
#  9   position          2612 non-null   object
#  10  shirt_nr          2612 non-null   int64
#  11  foot              2576 non-null   object
#  12  club              2612 non-null   object
#  13  contract_expires  2544 non-null   object
#  14  joined_club       2612 non-null   object
#  15  player_agent      2353 non-null   object
#  16  outfitter         1003 non-null   object
#  17  league            2612 non-null   object
# dtypes: float64(3), int64(3), object(12)
# memory usage: 367.4+ KB

# %%
data.describe()
# Out:
#         Unnamed: 0          age       height        price    max_price  \
# count  2612.000000  2612.000000  2601.000000  2602.000000  2606.000000
# mean   1305.500000    26.305513     1.830892    10.650711    17.304729
# std     754.163775     4.645297     0.067255    15.773271    21.948577
# min       0.000000    17.000000     1.630000     0.025000     0.025000
# 25%     652.750000    23.000000     1.780000     1.800000     3.500000
# 50%    1305.500000    26.000000     1.830000     4.500000    10.000000
# 75%    1958.250000    30.000000     1.880000    13.000000    22.000000
# max    2611.000000    42.000000     2.060000   180.000000   200.000000
#
#           shirt_nr
# count  2612.000000
# mean     20.495789
# std      17.914206
# min       1.000000
# 25%       8.000000
# 50%      17.000000
# 75%      27.000000
# max      99.000000

# %%
data = data.drop(['shirt_nr' , 'full_name' , 'Unnamed: 0'] , axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2612 entries, 0 to 2611
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2612 non-null   object
#  1   age               2612 non-null   int64
#  2   height            2601 non-null   float64
#  3   nationality       2612 non-null   object
#  4   place_of_birth    2595 non-null   object
#  5   price             2602 non-null   float64
#  6   max_price         2606 non-null   float64
#  7   position          2612 non-null   object
#  8   foot              2576 non-null   object
#  9   club              2612 non-null   object
#  10  contract_expires  2544 non-null   object
#  11  joined_club       2612 non-null   object
#  12  player_agent      2353 non-null   object
#  13  outfitter         1003 non-null   object
#  14  league            2612 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 306.2+ KB

# %%
data.isnull().sum()
# Out:
# name                   0
# age                    0
# height                11
# nationality            0
# place_of_birth        17
# price                 10
# max_price              6
# position               0
# foot                  36
# club                   0
# contract_expires      68
# joined_club            0
# player_agent         259
# outfitter           1609
# league                 0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy= 'most_frequent')
data['place_of_birth']=imputer.fit_transform(data[['place_of_birth']])
data['player_agent']=imputer.fit_transform(data[['player_agent']])
data['contract_expires'] =imputer.fit_transform(data[['contract_expires']])
data['foot'] =imputer.fit_transform(data[['foot']])
data['outfitter'] =imputer.fit_transform(data[['outfitter']])

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer()

# %%
data['height']=imputer.fit_transform(data[['height']])
data['price']=imputer.fit_transform(data[['price']])
data['max_price']=imputer.fit_transform(data[['max_price']])

# %%
data.isnull().sum()
# Out:
# name                0
# age                 0
# height              0
# nationality         0
# place_of_birth      0
# price               0
# max_price           0
# position            0
# foot                0
# club                0
# contract_expires    0
# joined_club         0
# player_agent        0
# outfitter           0
# league              0
# dtype: int64

# %%
from datetime import datetime

# %%
data['contract_expires'] = pd.to_datetime(data['contract_expires'])
data['joined_club'] = pd.to_datetime(data['joined_club'])

# %%
from  datasist.structdata import detect_outliers

# %%
sns.boxplot(x='price',data=data)
# Out:
# <Axes: xlabel='price'>

# %%
outliers=detect_outliers(data,0,['max_price','price','height'])

# %%
outliers
# Out:
# [0,
#  3,
#  5,
#  6,
#  10,
#  12,
#  13,
#  15,
#  16,
#  17,
#  19,
#  20,
#  21,
#  22,
#  23,
#  25,
#  28,
#  30,
#  33,
#  34,
#  36,
#  38,
#  39,
#  45,
#  46,
#  47,
#  48,
#  49,
#  51,
#  52,
#  55,
#  58,
#  59,
#  64,
#  66,
#  67,
#  69,
#  70,
#  73,
#  75,
#  77,
#  79,
#  82,
#  88,
#  90,
#  92,
#  94,
#  95,
#  97,
#  103,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  112,
#  113,
#  114,
#  123,
#  125,
#  127,
#  128,
#  131,
#  132,
#  133,
#  136,
#  138,
#  139,
#  145,
#  147,
#  148,
#  155,
#  160,
#  161,
#  162,
#  164,
#  165,
#  181,
#  192,
#  204,
#  231,
#  234,
#  237,
#  247,
#  261,
#  277,
#  292,
#  293,
#  334,
#  383,
#  432,
#  456,
#  477,
#  501,
#  537,
#  538,
#  539,
#  540,
#  542,
#  547,
#  548,
#  550,
#  553,
#  554,
#  555,
#  556,
#  557,
#  565,
#  566,
#  580,
#  582,
#  584,
#  599,
#  612,
#  616,
#  617,
#  639,
#  642,
#  644,
#  669,
#  673,
#  1052,
#  1062,
#  1065,
#  1068,
#  1073,
#  1079,
#  1084,
#  1089,
#  1098,
#  1108,
#  1109,
#  1110,
#  1119,
#  1121,
#  1129,
#  1130,
#  1139,
#  1145,
#  1146,
#  1152,
#  1154,
#  1156,
#  1199,
#  1207,
#  1208,
#  1213,
#  1224,
#  1225,
#  1235,
#  1261,
#  1337,
#  1465,
#  1603,
#  1606,
#  1607,
#  1608,
#  1611,
#  1612,
#  1615,
#  1616,
#  1617,
#  1618,
#  1620,
#  1621,
#  1622,
#  1623,
#  1624,
#  1625,
#  1628,
#  1631,
#  1632,
#  1637,
#  1638,
#  1639,
#  1640,
#  1641,
#  1642,
#  1643,
#  1645,
#  1646,
#  1647,
#  1648,
#  1649,
#  1650,
#  1652,
#  1662,
#  1663,
#  1664,
#  1666,
#  1669,
#  1670,
#  1671,
#  1684,
#  1689,
#  1690,
#  1699,
#  1711,
#  1736,
#  1768,
#  1780,
#  1795,
#  1812,
#  1813,
#  1818,
#  1966,
#  2094,
#  2097,
#  2100,
#  2101,
#  2103,
#  2107,
#  2109,
#  2110,
#  2114,
#  2115,
#  2116,
#  2141,
#  2170,
#  2184,
#  2192,
#  2215,
#  2233,
#  2238,
#  2239,
#  2263,
#  4,
#  7,
#  29,
#  41,
#  42,
#  53,
#  56,
#  62,
#  71,
#  74,
#  83,
#  84,
#  101,
#  118,
#  121,
#  151,
#  154,
#  170,
#  182,
#  185,
#  187,
#  188,
#  190,
#  196,
#  205,
#  207,
#  212,
#  238,
#  257,
#  258,
#  264,
#  281,
#  286,
#  289,
#  309,
#  324,
#  335,
#  362,
#  397,
#  398,
#  448,
#  460,
#  461,
#  468,
#  476,
#  492,
#  543,
#  549,
#  560,
#  564,
#  586,
#  590,
#  591,
#  613,
#  624,
#  630,
#  651,
#  667,
#  692,
#  703,
#  1060,
#  1063,
#  1072,
#  1075,
#  1080,
#  1090,
#  1122,
#  1135,
#  1142,
#  1163,
#  1174,
#  1180,
#  1181,
#  1187,
#  1203,
#  1633,
#  1635,
#  1661,
#  1668,
#  1674,
#  1682,
#  1687,
#  1715,
#  1717,
#  1763,
#  1833,
#  2098,
#  2108,
#  2166,
#  2196,
#  2206,
#  2281,
#  189,
#  332,
#  2530]

# %%
out=data.loc[outliers]
clean=data.drop(outliers,axis=0)

# %%
data
# Out:
#                     name  age    height                 nationality  \
# 0                Ederson   29  1.880000            Brazil  Portugal
# 1          Stefan Ortega   30  1.850000              Germany  Spain
# 2           Scott Carson   37  1.880000                     England
# 3             Rúben Dias   26  1.870000                    Portugal
# 4             Nathan Aké   28  1.800000  Netherlands  Cote d'Ivoire
# ...                  ...  ...       ...                         ...
# 2607       Moussa Djitté   23  1.800000                     Senegal
# 2608  Mounaïm El Idrissy   24  1.810000             France  Morocco
# 2609      Moussa Soumano   17  1.830892                France  Mali
# 2610      Romain Hamouma   36  1.790000             France  Algeria
# 2611      Yoann Touzghar   36  1.800000             Tunisia  France
#
#      place_of_birth  price  max_price                 position   foot  \
# 0       Osasco (SP)  45.00      70.00               Goalkeeper   left
# 1        Hofgeismar   6.00       6.00               Goalkeeper  right
# 2        Whitehaven   0.25       6.00               Goalkeeper  right
# 3           Amadora  75.00      75.00   Defender - Centre-Back  right
# 4          Den Haag  35.00      40.00   Defender - Centre-Back   left
# ...             ...    ...        ...                      ...    ...
# 2607      Diattouma   2.00       2.00  Attack - Centre-Forward  right
# 2608      Martigues   1.80       1.80  Attack - Centre-Forward  right
# 2609         London   0.90       0.90  Attack - Centre-Forward  right
# 2610    Montbéliard   0.60       7.00  Attack - Centre-Forward  right
# 2611        Avignon   0.50       1.75  Attack - Centre-Forward  right
#
#             club contract_expires joined_club        player_agent outfitter  \
# 0       Man City       2026-06-30  2017-07-01           Gestifute      Puma
# 1       Man City       2025-06-30  2022-07-01         neblung ...      Nike
# 2       Man City       2023-06-30  2021-07-20           Wasserman      Puma
# 3       Man City       2027-06-30  2020-09-29           Gestifute      Nike
# 4       Man City       2025-06-30  2020-08-05           Wasserman      Nike
# ...          ...              ...         ...                 ...       ...
# 2607  AC Ajaccio       2023-06-30  2023-01-31       FS Management      Nike
# 2608  AC Ajaccio       2023-06-30  2019-07-01            N.Agency      Nike
# 2609  AC Ajaccio       2026-06-30  2023-01-01           Wasserman      Nike
# 2610  AC Ajaccio       2023-06-30  2022-07-01  Gallea Gestion S.A      Nike
# 2611  AC Ajaccio       2024-06-30  2022-08-24         AGJ SP MGMT      Nike
#
#      league
# 0       EPL
# 1       EPL
# 2       EPL
# 3       EPL
# 4       EPL
# ...     ...
# 2607  Other
# 2608  Other
# 2609  Other
# 2610  Other
# 2611  Other
#
# [2612 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2612 entries, 0 to 2611
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2612 non-null   object
#  1   age               2612 non-null   int64
#  2   height            2612 non-null   float64
#  3   nationality       2612 non-null   object
#  4   place_of_birth    2612 non-null   object
#  5   price             2612 non-null   float64
#  6   max_price         2612 non-null   float64
#  7   position          2612 non-null   object
#  8   foot              2612 non-null   object
#  9   club              2612 non-null   object
#  10  contract_expires  2612 non-null   datetime64[ns]
#  11  joined_club       2612 non-null   datetime64[ns]
#  12  player_agent      2612 non-null   object
#  13  outfitter         2612 non-null   object
#  14  league            2612 non-null   object
#  15  Duration          2612 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(1), object(9), timedelta64[ns](1)
# memory usage: 326.6+ KB

# %%
#what is the highest age?
data[data['age'] == data['age'].max()]
#cars[cars['price'] == cars['price'].max()]
# Out:
#                    name  age  height nationality      place_of_birth  price  \
# 1264    Gianluca Pegolo   42    1.83       Italy  Bassano del Grappa   0.10
# 2372  Nicolas Penneteau   42    1.85      France           Marseille   0.15
#
#       max_price    position  foot         club contract_expires joined_club  \
# 1264        2.0  Goalkeeper  left     Sassuolo       2023-06-30  2013-09-02
# 2372        2.8  Goalkeeper  left  Stade Reims       2023-06-30  2021-07-01
#
#        player_agent outfitter  league  Duration
# 1264  P&P Sport ...      Nike  SerieA 3588 days
# 2372      USM GROUP      Nike  Ligue1  729 days

# %%
#what is the tallest height ?
data[data['height'] == data['height'].max()]
# Out:
#              name  age  height            nationality place_of_birth  price  \
# 2530  Isaak Touré   20    2.06  France  Cote d'Ivoire        Gonesse    5.0
#
#       max_price                position  foot        club contract_expires  \
# 2530        5.0  Defender - Centre-Back  left  AJ Auxerre       2023-06-30
#
#      joined_club          player_agent outfitter league Duration
# 2530  2023-01-03  ND SPORTS MANAGEMENT      Nike  Other 178 days

# %%
#what is the highest price?
data[data['price'] == data['price'].max()]
# Out:
#                name  age  height       nationality place_of_birth  price  \
# 2116  Kylian Mbappé   24    1.78  France  Cameroon          Bondy  180.0
#
#       max_price                 position   foot      club contract_expires  \
# 2116      200.0  Attack - Centre-Forward  right  Paris SG       2025-06-30
#
#      joined_club player_agent outfitter  league  Duration
# 2116  2018-07-01    Relatives      Nike  Ligue1 2556 days

# %%
data['nationality'].mode()
# Out:
# 0    Spain
# Name: nationality, dtype: object

# %%
sns.countplot(x = 'position' , data = data)
# Out:
# <Axes: xlabel='position', ylabel='count'>

# %%
sns.countplot(x = 'league' , data=data)
# Out:
# <Axes: xlabel='league', ylabel='count'>

# %%
sns.countplot(x = 'foot' , data=data)
# Out:
# <Axes: xlabel='foot', ylabel='count'>

# %%
sns.countplot(x = 'outfitter' , data=data)
# Out:
# <Axes: xlabel='outfitter', ylabel='count'>

# %%
data.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8752\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                 age    height     price  max_price
# age        1.000000  0.050234 -0.122956   0.125288
# height     0.050234  1.000000 -0.056256  -0.085045
# price     -0.122956 -0.056256  1.000000   0.818202
# max_price  0.125288 -0.085045  0.818202   1.000000

# %%
sns.heatmap(data.corr() , annot=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8752\3001495479.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr() , annot=True)
# <Axes: >
